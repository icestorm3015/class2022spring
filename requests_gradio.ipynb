# %% [markdown]
# <a href="https://colab.research.google.com/github/icestorm3015/class2022spring/blob/main/requests_gradio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gradio
import gradio as gr
import requests
import pandas as pd

# %%
URL = ('http://apis.data.go.kr/B552584/ArpltnStatsSvc/'
      'getCtprvnMesureSidoLIst?'
      'sidoName=서울'
      '&searchCondition=hour'
      '&pageNo=1'
      '&numOfRows=100'
      '&returnType=json'
      '&serviceKey=miH%2BZXg85lQy4%2FkmhffvygXDIFiTwisriSLxtyECSzw6hxTVK7yI8QKIOc7mP7LEqCnhBGuj6iW1gZW65dum7A%3D%3D')
response = requests.get(URL)

# %% [markdown]
# #### http://jsonviewer.stack.hu/ (copy json here to view json)

# %%
r = response.json()
r
# Out:
# {'response': {'body': {'items': [{'cityName': '강남구',
#      'cityNameEng': 'Gangnam-gu',
#      'coValue': '',
#      'dataGubun': '',
#      'dataTime': '2022-04-19 10:00',
#      'districtCode': '02',
#      'districtNumSeq': '001',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '',
#      'numOfRows': '10',
#      'o3Value': '',
#      'pageNo': '1',
#      'pm10Value': '',
#      'pm25Value': '',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '',
#      'totalCount': ''},
#     {'cityName': '강동구',
#      'cityNameEng': 'Gangdong-gu',
#      'coValue': '',
#      'dataGubun': '',
#      'dataTime': '2022-04-19 10:00',
#      'districtCode': '02',
#      'districtNumSeq': '002',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '',
#      'numOfRows': '10',
#      'o3Value': '',
#      'pageNo': '1',
#      'pm10Value': '',
#      'pm25Value': '',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '',
#      'totalCount': ''},
#     {'cityName': '강북구',
#      'cityNameEng': 'Gangbuk-gu',
#      'coValue': '',
#      'dataGubun': '',
#      'dataTime': '2022-04-19 10:00',
#      'districtCode': '02',
#      'districtNumSeq': '003',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '',
#      'numOfRows': '10',
#      'o3Value': '',
#      'pageNo': '1',
#      'pm10Value': '',
#      'pm25Value': '',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '',
#      'totalCount': ''},
#     {'cityName': '강서구',
#      'cityNameEng': 'Gangseo-gu',
#      'coValue': '',
#      'dataGubun': '',
#      'dataTime': '2022-04-19 10:00',
#      'districtCode': '02',
#      'districtNumSeq': '004',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '',
#      'numOfRows': '10',
#      'o3Value': '',
#      'pageNo': '1',
#      'pm10Value': '',
#      'pm25Value': '',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '',
#      'totalCount': ''},
#     {'cityName': '관악구',
#      'cityNameEng': 'Gwanak-gu',
#      'coValue': '',
#      'dataGubun': '',
#      'dataTime': '2022-04-19 10:00',
#      'districtCode': '02',
#      'districtNumSeq': '005',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '',
#      'numOfRows': '10',
#      'o3Value': '',
#      'pageNo': '1',
#      'pm10Value': '',
#      'pm25Value': '',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '',
#      'totalCount': ''},
#     {'cityName': '광진구',
#      'cityNameEng': 'Gwangjin-gu',
#      'coValue': '',
#      'dataGubun': '',
#      'dataTime': '2022-04-19 10:00',
#      'districtCode': '02',
#      'districtNumSeq': '006',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '',
#      'numOfRows': '10',
#      'o3Value': '',
#      'pageNo': '1',
#      'pm10Value': '',
#      'pm25Value': '',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '',
#      'totalCount': ''},
#     {'cityName': '구로구',
#      'cityNameEng': 'Guro-gu',
#      'coValue': '',
#      'dataGubun': '',
#      'dataTime': '2022-04-19 10:00',
#      'districtCode': '02',
#      'districtNumSeq': '007',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '',
#      'numOfRows': '10',
#      'o3Value': '',
#      'pageNo': '1',
#      'pm10Value': '',
#      'pm25Value': '',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '',
#      'totalCount': ''},
#     {'cityName': '금천구',
#      'cityNameEng': 'Geumcheon-gu',
#      'coValue': '',
#      'dataGubun': '',
#      'dataTime': '2022-04-19 10:00',
#      'districtCode': '02',
#      'districtNumSeq': '008',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '',
#      'numOfRows': '10',
#      'o3Value': '',
#      'pageNo': '1',
#      'pm10Value': '',
#      'pm25Value': '',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '',
#      'totalCount': ''},
#     {'cityName': '노원구',
#      'cityNameEng': 'Nowon-gu',
#      'coValue': '',
#      'dataGubun': '',
#      'dataTime': '2022-04-19 10:00',
#      'districtCode': '02',
#      'districtNumSeq': '009',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '',
#      'numOfRows': '10',
#      'o3Value': '',
#      'pageNo': '1',
#      'pm10Value': '',
#      'pm25Value': '',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '',
#      'totalCount': ''},
#     {'cityName': '도봉구',
#      'cityNameEng': 'Dobong-gu',
#      'coValue': '',
#      'dataGubun': '',
#      'dataTime': '2022-04-19 10:00',
#      'districtCode': '02',
#      'districtNumSeq': '010',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '',
#      'numOfRows': '10',
#      'o3Value': '',
#      'pageNo': '1',
#      'pm10Value': '',
#      'pm25Value': '',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '',
#      'totalCount': ''},
#     {'cityName': '동대문구',
#      'cityNameEng': 'Dongdaemun-gu',
#      'coValue': '',
#      'dataGubun': '',
#      'dataTime': '2022-04-19 10:00',
#      'districtCode': '02',
#      'districtNumSeq': '011',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '',
#      'numOfRows': '10',
#      'o3Value': '',
#      'pageNo': '1',
#      'pm10Value': '',
#      'pm25Value': '',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '',
#      'totalCount': ''},
#     {'cityName': '동작구',
#      'cityNameEng': 'Dongjak-gu',
#      'coValue': '',
#      'dataGubun': '',
#      'dataTime': '2022-04-19 10:00',
#      'districtCode': '02',
#      'districtNumSeq': '012',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '',
#      'numOfRows': '10',
#      'o3Value': '',
#      'pageNo': '1',
#      'pm10Value': '',
#      'pm25Value': '',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '',
#      'totalCount': ''},
#     {'cityName': '마포구',
#      'cityNameEng': 'Mapo-gu',
#      'coValue': '',
#      'dataGubun': '',
#      'dataTime': '2022-04-19 10:00',
#      'districtCode': '02',
#      'districtNumSeq': '013',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '',
#      'numOfRows': '10',
#      'o3Value': '',
#      'pageNo': '1',
#      'pm10Value': '',
#      'pm25Value': '',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '',
#      'totalCount': ''},
#     {'cityName': '서대문구',
#      'cityNameEng': 'Seodaemun-gu',
#      'coValue': '',
#      'dataGubun': '',
#      'dataTime': '2022-04-19 10:00',
#      'districtCode': '02',
#      'districtNumSeq': '014',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '',
#      'numOfRows': '10',
#      'o3Value': '',
#      'pageNo': '1',
#      'pm10Value': '',
#      'pm25Value': '',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '',
#      'totalCount': ''},
#     {'cityName': '서초구',
#      'cityNameEng': 'Seocho-gu',
#      'coValue': '',
#      'dataGubun': '',
#      'dataTime': '2022-04-19 10:00',
#      'districtCode': '02',
#      'districtNumSeq': '015',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '',
#      'numOfRows': '10',
#      'o3Value': '',
#      'pageNo': '1',
#      'pm10Value': '',
#      'pm25Value': '',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '',
#      'totalCount': ''},
#     {'cityName': '성동구',
#      'cityNameEng': 'Seongdong-gu',
#      'coValue': '',
#      'dataGubun': '',
#      'dataTime': '2022-04-19 10:00',
#      'districtCode': '02',
#      'districtNumSeq': '016',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '',
#      'numOfRows': '10',
#      'o3Value': '',
#      'pageNo': '1',
#      'pm10Value': '',
#      'pm25Value': '',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '',
#      'totalCount': ''},
#     {'cityName': '성북구',
#      'cityNameEng': 'Seongbuk-gu',
#      'coValue': '',
#      'dataGubun': '',
#      'dataTime': '2022-04-19 10:00',
#      'districtCode': '02',
#      'districtNumSeq': '017',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '',
#      'numOfRows': '10',
#      'o3Value': '',
#      'pageNo': '1',
#      'pm10Value': '',
#      'pm25Value': '',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '',
#      'totalCount': ''},
#     {'cityName': '송파구',
#      'cityNameEng': 'Songpa-gu',
#      'coValue': '',
#      'dataGubun': '',
#      'dataTime': '2022-04-19 10:00',
#      'districtCode': '02',
#      'districtNumSeq': '018',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '',
#      'numOfRows': '10',
#      'o3Value': '',
#      'pageNo': '1',
#      'pm10Value': '',
#      'pm25Value': '',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '',
#      'totalCount': ''},
#     {'cityName': '양천구',
#      'cityNameEng': 'Yangcheon-gu',
#      'coValue': '',
#      'dataGubun': '',
#      'dataTime': '2022-04-19 10:00',
#      'districtCode': '02',
#      'districtNumSeq': '019',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '',
#      'numOfRows': '10',
#      'o3Value': '',
#      'pageNo': '1',
#      'pm10Value': '',
#      'pm25Value': '',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '',
#      'totalCount': ''},
#     {'cityName': '영등포구',
#      'cityNameEng': 'Yeongdeungpo-gu',
#      'coValue': '',
#      'dataGubun': '',
#      'dataTime': '2022-04-19 10:00',
#      'districtCode': '02',
#      'districtNumSeq': '020',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '',
#      'numOfRows': '10',
#      'o3Value': '',
#      'pageNo': '1',
#      'pm10Value': '',
#      'pm25Value': '',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '',
#      'totalCount': ''},
#     {'cityName': '용산구',
#      'cityNameEng': 'Yongsan-gu',
#      'coValue': '',
#      'dataGubun': '',
#      'dataTime': '2022-04-19 10:00',
#      'districtCode': '02',
#      'districtNumSeq': '021',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '',
#      'numOfRows': '10',
#      'o3Value': '',
#      'pageNo': '1',
#      'pm10Value': '',
#      'pm25Value': '',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '',
#      'totalCount': ''},
#     {'cityName': '은평구',
#      'cityNameEng': 'Eunpyeong-gu',
#      'coValue': '',
#      'dataGubun': '',
#      'dataTime': '2022-04-19 10:00',
#      'districtCode': '02',
#      'districtNumSeq': '022',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '',
#      'numOfRows': '10',
#      'o3Value': '',
#      'pageNo': '1',
#      'pm10Value': '',
#      'pm25Value': '',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '',
#      'totalCount': ''},
#     {'cityName': '종로구',
#      'cityNameEng': 'Jongno-gu',
#      'coValue': '',
#      'dataGubun': '',
#      'dataTime': '2022-04-19 10:00',
#      'districtCode': '02',
#      'districtNumSeq': '023',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '',
#      'numOfRows': '10',
#      'o3Value': '',
#      'pageNo': '1',
#      'pm10Value': '',
#      'pm25Value': '',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '',
#      'totalCount': ''},
#     {'cityName': '중구',
#      'cityNameEng': 'Jung-gu',
#      'coValue': '',
#      'dataGubun': '',
#      'dataTime': '2022-04-19 10:00',
#      'districtCode': '02',
#      'districtNumSeq': '024',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '',
#      'numOfRows': '10',
#      'o3Value': '',
#      'pageNo': '1',
#      'pm10Value': '',
#      'pm25Value': '',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '',
#      'totalCount': ''},
#     {'cityName': '중랑구',
#      'cityNameEng': 'Jungnang-gu',
#      'coValue': '',
#      'dataGubun': '',
#      'dataTime': '2022-04-19 10:00',
#      'districtCode': '02',
#      'districtNumSeq': '025',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '',
#      'numOfRows': '10',
#      'o3Value': '',
#      'pageNo': '1',
#      'pm10Value': '',
#      'pm25Value': '',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '',
#      'totalCount': ''}],
#    'numOfRows': 100,
#    'pageNo': 1,
#    'totalCount': 25},
#   'header': {'resultCode': '00', 'resultMsg': 'NORMAL_CODE'}}}

# %%
items = r['response']['body']['items']

cityName = [item['cityName'] for item in items]
pm10Value = [item['pm10Value'] for item in items]
pm25Value = [item['pm25Value'] for item in items]
so2Value = [item['so2Value'] for item in items]
coValue = [item['coValue'] for item in items]
o3Value = [item['o3Value'] for item in items]
no2Value = [item['no2Value'] for item in items]

cityName = pd.Series(cityName)
pm10Value = pd.Series(pm10Value)   
pm25Value = pd.Series(pm25Value)
so2Value = pd.Series(so2Value)
coValue = pd.Series(coValue)
o3Value = pd.Series(o3Value)
no2Value = pd.Series(no2Value)

df = pd.DataFrame({ 'cityName': cityName, 'pm10Value': pm10Value, 'pm25Value': pm25Value, 'so2Value': so2Value, 'coValue': coValue, 'o3Value': o3Value, 'no2Value': no2Value})

# %%
def test(sidoName):
  URL = ('http://apis.data.go.kr/B552584/ArpltnStatsSvc/'
      'getCtprvnMesureSidoLIst?'
      'sidoName='+sidoName+
      '&searchCondition=hour'
      '&pageNo=1'
      '&numOfRows=100'
      '&returnType=json'
      '&serviceKey=miH%2BZXg85lQy4%2FkmhffvygXDIFiTwisriSLxtyECSzw6hxTVK7yI8QKIOc7mP7LEqCnhBGuj6iW1gZW65dum7A%3D%3D')
  
  response = requests.get(URL)
  r = response.json()
  items = r['response']['body']['items']

  cityName = [item['cityName'] for item in items]
  pm10Value = [item['pm10Value'] for item in items]
  pm25Value = [item['pm25Value'] for item in items]
  so2Value = [item['so2Value'] for item in items]
  coValue = [item['coValue'] for item in items]
  o3Value = [item['o3Value'] for item in items]
  no2Value = [item['no2Value'] for item in items]

  cityName = pd.Series(cityName)
  pm10Value = pd.Series(pm10Value)   
  pm25Value = pd.Series(pm25Value)
  so2Value = pd.Series(so2Value)
  coValue = pd.Series(coValue)
  o3Value = pd.Series(o3Value)
  no2Value = pd.Series(no2Value)

  df = pd.DataFrame({ 'cityName': cityName, 'pm10Value': pm10Value, 'pm25Value': pm25Value, 'so2Value': so2Value, 'coValue': coValue, 'o3Value': o3Value, 'no2Value': no2Value})
  return df

# %%
iface = gr.Interface(test, gr.inputs.Dropdown(['서울', '부산', '대구', '인천', '광주', '대전', '울산', '경기', '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주', '세종']), outputs=['dataframe'])
iface.launch(debug=True)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://15069.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces (https://huggingface.co/spaces)
#         <iframe
#             width="900"
#             height="500"
#             src="https://15069.gradio.app"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
